# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from pandas import DataFrame
import json

# %%
url = "https://ca.trustpilot.com/review/"
p = "www."
q = "samsung"
s = ".com"
req = requests.get(url+p+q+s)
text = req.content

# %%
(url+p+q+s)
# Out:
# 'https://ca.trustpilot.com/review/www.samsung.com'

# %%
soup = BeautifulSoup(text)
reviews = soup.find_all(class_='review-card')
reviews
# Out:
# [<div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="6064ed12e3c5e0001ae0fb81" data-reviewmid="6064ed45f85d750870413322" id="6064ed45f85d750870413322">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/6064ed45f85d750870413322","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"6064ed12e3c5e0001ae0fb81","consumerName":"H.H","reviewId":"6064ed45f85d750870413322","reviewHeader":"I would give five 0’s if I could","reviewBody":"I would give five 0’s if I could. They hanged up 3 times.First I was told the old, “we are have a bad connection, I’ll call you back .Never call back. The others , just hanged up. The chat is terrible, it keeps stating the same thing, over. Or transfer you to some else. Typing is a problem, because it continues to jump.I made a purchase,and it will be my last. Apple treats their customers,so much better. Give the jobs to people that want to work.I worked it customers for 45 years ,and received awards,which I was surprised to receive.","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/6064ed12e3c5e0001ae0fb81">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="H.H" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              H.H
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>1 review</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>US</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-31T21:44:37+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/6064ed45f85d750870413322">
#                          I would give five 0’s if I could
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  I would give five 0’s if I could. They hanged up 3 times.First I was told the old, “we are have a bad connection, I’ll call you back .Never call back. The others , just hanged up. The chat is terrible, it keeps stating the same thing, over. Or transfer you to some else. Typing is a problem, because it continues to jump.I made a purchase,and it will be my last. Apple treats their customers,so much better. Give the jobs to people that want to work.I worked it customers for 45 years ,and received awards,which I was surprised to receive.
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="6064ed45f85d750870413322">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/6064ed45f85d750870413322?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="6064d3dde3c5e0001ae0f033" data-reviewmid="6064d409f85d7508704105bb" id="6064d409f85d7508704105bb">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/6064d409f85d7508704105bb","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"6064d3dde3c5e0001ae0f033","consumerName":"John ","reviewId":"6064d409f85d7508704105bb","reviewHeader":"The Samsung Reputation","reviewBody":"I have worked in tech support for many years, in a smaller company. I could not believe the level of knowledge, candor, and problem-solving skills of the support agents at Samsung. I found that as I pursued my question (Where can i find the APK file i just downloaded) I only got more frustrated. My first email was met with a response, telling me they are unable to help. A quick one-line response, i bet it was copy and pasted. No direction on how to solve it, no helpful tips on what to do, nothing. So seeing as my email didn\u0027t work, I took time while at work to jump on and speak with a live agent. From the moment we started to speak i could tell i was being rushed through and bothering him with my questions. Not only was this not a timely/quick endeavor, but I was getting help from google not Samsung. The solutions i tried are very clear responses the agent is asking google because they didn\u0027t work and had no evidence of background knowledge on the subject. This i think will forever sour my idea of Samsung. These phones are far from cheap, and the company is global. I can almost guarantee that with a product as unique as this and no form of reliable support, i will not be choosing this company again. \n\nAlmost forgot. I catch the most unethical things about this company and how they treat their clients. Not only is the \u00221-5 star feedback bar\u0022 configured to auto pick 5 stars. The options under the text box that i write this is, has more unethical options. \u0022How quick did the company reply to your queries?\u0022 This option jumps from 6-12 hours to over a week. Not leaving options for the more likely case, it took a couple of days to respond. Im appalled by this and many things i am finding out about Samsung. Luckily i work for a global company as well, and can make sure we take Galaxy phones off of our list for our employees. If we are going to spend this money, we will go with a better company. \n\nAlso as i scroll i see that this is not news to most. That most people have issues with this company, judging by the reviews. I will be copying and paste this to as many review sites as i can, hopefully, I can help stop people from walking down the same road as the rest of us.\n\n(This was copy and pasted from the review I wrote for their website)","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/6064d3dde3c5e0001ae0f033">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="John " image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              John
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>1 review</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>CA</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-31T19:56:57+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/6064d409f85d7508704105bb">
#                          The Samsung Reputation
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  I have worked in tech support for many years, in a smaller company. I could not believe the level of knowledge, candor, and problem-solving skills of the support agents at Samsung. I found that as I pursued my question (Where can i find the APK file i just downloaded) I only got more frustrated. My first email was met with a response, telling me they are unable to help. A quick one-line response, i bet it was copy and pasted. No direction on how to solve it, no helpful tips on what to do, nothing. So seeing as my email didn't work, I took time while at work to jump on and speak with a live agent. From the moment we started to speak i could tell i was being rushed through and bothering him with my questions. Not only was this not a timely/quick endeavor, but I was getting help from google not Samsung. The solutions i tried are very clear responses the agent is asking google because they didn't work and had no evidence of background knowledge on the subject. This i think will forever sour my idea of Samsung. These phones are far from cheap, and the company is global. I can almost guarantee that with a product as unique as this and no form of reliable support, i will not be choosing this company again. <br/><br/>Almost forgot. I catch the most unethical things about this company and how they treat their clients. Not only is the "1-5 star feedback bar" configured to auto pick 5 stars. The options under the text box that i write this is, has more unethical options. "How quick did the company reply to your queries?" This option jumps from 6-12 hours to over a week. Not leaving options for the more likely case, it took a couple of days to respond. Im appalled by this and many things i am finding out about Samsung. Luckily i work for a global company as well, and can make sure we take Galaxy phones off of our list for our employees. If we are going to spend this money, we will go with a better company. <br/><br/>Also as i scroll i see that this is not news to most. That most people have issues with this company, judging by the reviews. I will be copying and paste this to as many review sites as i can, hopefully, I can help stop people from walking down the same road as the rest of us.<br/><br/>(This was copy and pasted from the review I wrote for their website)
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="6064d409f85d7508704105bb">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/6064d409f85d7508704105bb?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="603bde30f560680019db895f" data-reviewmid="60634490f85d7508703e2eef" id="60634490f85d7508703e2eef">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/60634490f85d7508703e2eef","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"603bde30f560680019db895f","consumerName":"Bryan Brown","reviewId":"60634490f85d7508703e2eef","reviewHeader":"Galaxy watch","reviewBody":"I have been a Samsung customer for countless years. Since I\u0027ve purchased my galaxy watch its has had battery issues. They they denied but then fixed. This time coming around I\u0027ve recently updated my software on my watch and now the watch will not stay on. It just keeps shutting down. Now Samsung is charging me 117.00 to fix a manufacturer issue that they know that causes this watch to malfunction with either battery issues or software issues. Nonetheless I am not happy with Samsung at this moment because I value my electronics and the quality of what I buy from Samsung. This is ridiculous that I I have to pay for a malfunction in their product which they already knows that malfunctioning.","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/603bde30f560680019db895f">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="Bryan Brown" consumer-image-url="https://user-images.trustpilot.com/603bde30f560680019db895f/73x73.png" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              Bryan Brown
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>2 reviews</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>US</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-30T15:32:32+00:00","updatedDate":"2021-03-30T15:37:45+00:00","reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/60634490f85d7508703e2eef">
#                          Galaxy watch
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  I have been a Samsung customer for countless years. Since I've purchased my galaxy watch its has had battery issues. They they denied but then fixed. This time coming around I've recently updated my software on my watch and now the watch will not stay on. It just keeps shutting down. Now Samsung is charging me 117.00 to fix a manufacturer issue that they know that causes this watch to malfunction with either battery issues or software issues. Nonetheless I am not happy with Samsung at this moment because I value my electronics and the quality of what I buy from Samsung. This is ridiculous that I I have to pay for a malfunction in their product which they already knows that malfunctioning.
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="60634490f85d7508703e2eef">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/60634490f85d7508703e2eef?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="5e468c5b68c4b96932c97930" data-reviewmid="606322e7f85d7508703dd660" id="606322e7f85d7508703dd660">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/606322e7f85d7508703dd660","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"5e468c5b68c4b96932c97930","consumerName":"ATEF Eldin","reviewId":"606322e7f85d7508703dd660","reviewHeader":"I bought a Samsung Galaxy fold on line…","reviewBody":"I bought a Samsung Galaxy fold on line from Samsung direct .Big mistake Samsung after servise is the worst no support for there products the give you the runaround to avoid taking any responsabilty they do not houner there warenty either disaster on all fronts.\nMy Galacy fold droped two pixels on the screen after 8 months send it for repair was told resen this happened i was presing to hard on the screen what an excuse the screen is to sensetive which is the problem Samsung had on this model and the phone was withdrawn .insted of dealing with problem they gave me a bill £550 for repaire one third of the value of the phone.\naparently there is insurance that covers the screen but it is only available if i buy the phone from a retailer so why is Samsung encouraging the public to buy direct from them .The phone is bad the after sales servise is even worse totaly missleding information it is unbeleivable that a large corporation as big as Samsung can behave  this way.\nWarrning  do not buy Samsung Galexy Fold its a bad phone","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/5e468c5b68c4b96932c97930">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="ATEF Eldin" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              ATEF Eldin
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>4 reviews</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>GB</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-30T13:08:55+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/606322e7f85d7508703dd660">
#                          I bought a Samsung Galaxy fold on line…
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  I bought a Samsung Galaxy fold on line from Samsung direct .Big mistake Samsung after servise is the worst no support for there products the give you the runaround to avoid taking any responsabilty they do not houner there warenty either disaster on all fronts.<br/>My Galacy fold droped two pixels on the screen after 8 months send it for repair was told resen this happened i was presing to hard on the screen what an excuse the screen is to sensetive which is the problem Samsung had on this model and the phone was withdrawn .insted of dealing with problem they gave me a bill £550 for repaire one third of the value of the phone.<br/>aparently there is insurance that covers the screen but it is only available if i buy the phone from a retailer so why is Samsung encouraging the public to buy direct from them .The phone is bad the after sales servise is even worse totaly missleding information it is unbeleivable that a large corporation as big as Samsung can behave  this way.<br/>Warrning  do not buy Samsung Galexy Fold its a bad phone
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="606322e7f85d7508703dd660">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/606322e7f85d7508703dd660?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="6013ad8c7712370019539f2e" data-reviewmid="60623510f85d7508703c9d2f" id="60623510f85d7508703c9d2f">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/60623510f85d7508703c9d2f","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"6013ad8c7712370019539f2e","consumerName":"Wayne F","reviewId":"60623510f85d7508703c9d2f","reviewHeader":"Samsung Supplying Used Items","reviewBody":"Received a washing machine which was meant to be brand new. Unpacked it and the drum was full of water, scratches on the front and washing powder in the groves.\n\nCant get through to anyone and its foreigners who cant talk english. \n\nI was on hold for over an hour after complaining. Joke.\n\nThey stated that before they can send me a replacement i have to wait 10 days. Still waiting for a call back to to resolve the issue and return the item. All my emails are ignored.\n\nThe worst customer service i have ever dealt with. I wont be buying any Samsung products again.\n\nI have just opened a case with Paypal.","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/6013ad8c7712370019539f2e">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="Wayne F" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              Wayne F
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>2 reviews</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>GB</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-29T20:14:08+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/60623510f85d7508703c9d2f">
#                          Samsung Supplying Used Items
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  Received a washing machine which was meant to be brand new. Unpacked it and the drum was full of water, scratches on the front and washing powder in the groves.<br/><br/>Cant get through to anyone and its foreigners who cant talk english. <br/><br/>I was on hold for over an hour after complaining. Joke.<br/><br/>They stated that before they can send me a replacement i have to wait 10 days. Still waiting for a call back to to resolve the issue and return the item. All my emails are ignored.<br/><br/>The worst customer service i have ever dealt with. I wont be buying any Samsung products again.<br/><br/>I have just opened a case with Paypal.
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="60623510f85d7508703c9d2f">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/60623510f85d7508703c9d2f?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="605f78379645d1001979c06f" data-reviewmid="605f786bf85d75087038f822" id="605f786bf85d75087038f822">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/605f786bf85d75087038f822","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"605f78379645d1001979c06f","consumerName":"JRamos","reviewId":"605f786bf85d75087038f822","reviewHeader":"Ordered a Galaxy Tab S7 almost 2 month…","reviewBody":"Ordered a Galaxy Tab S7 almost 2 month ago but it got lost through shipping but they kept telling me to wait a little longer to see if they can find it through FDEX. After 3 attempts Samsung sent me an email saying that the money has been reimbursed and thank you for doing business with them, and asked me to buy a galaxy phone, even though I was trying to buy a tablet. No mention in their email to offer me free shipping for another tablet or any other gratitude for the mess they created.","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/605f78379645d1001979c06f">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="JRamos" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              JRamos
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>1 review</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>US</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-27T18:24:43+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/605f786bf85d75087038f822">
#                          Ordered a Galaxy Tab S7 almost 2 month…
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  Ordered a Galaxy Tab S7 almost 2 month ago but it got lost through shipping but they kept telling me to wait a little longer to see if they can find it through FDEX. After 3 attempts Samsung sent me an email saying that the money has been reimbursed and thank you for doing business with them, and asked me to buy a galaxy phone, even though I was trying to buy a tablet. No mention in their email to offer me free shipping for another tablet or any other gratitude for the mess they created.
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="605f786bf85d75087038f822">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/605f786bf85d75087038f822?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="605f122d9645d10019798c5d" data-reviewmid="605f151af85d7508703842a2" id="605f151af85d7508703842a2">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/605f151af85d7508703842a2","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"605f122d9645d10019798c5d","consumerName":"chetan Sood","reviewId":"605f151af85d7508703842a2","reviewHeader":"Guys","reviewBody":"Guys , I am genuine customer and victim of their planned s**t obsolescence, I bought a fridge which cost me around 37000 at door, not even a year , just within 15 months or so ..., It came up with problem ...out of nowhere , it\u0027s never been used to its extreme, services center helped zero and that services costed me 4000 , as they took to service center called it a component got faulty , really pathetic","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/605f122d9645d10019798c5d">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="chetan Sood" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              chetan Sood
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>1 review</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>IN</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-27T11:20:58+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/605f151af85d7508703842a2">
#                          Guys
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  Guys , I am genuine customer and victim of their planned s**t obsolescence, I bought a fridge which cost me around 37000 at door, not even a year , just within 15 months or so ..., It came up with problem ...out of nowhere , it's never been used to its extreme, services center helped zero and that services costed me 4000 , as they took to service center called it a component got faulty , really pathetic
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="605f151af85d7508703842a2">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/605f151af85d7508703842a2?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="605f0daad0a67f001977b89a" data-reviewmid="605f0e9cf85d75087038376a" id="605f0e9cf85d75087038376a">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/605f0e9cf85d75087038376a","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"605f0daad0a67f001977b89a","consumerName":"Preeti Gupta","reviewId":"605f0e9cf85d75087038376a","reviewHeader":"Samsung S20 Ultra","reviewBody":"Recently bought samsung s20 ultra. Its just the dream phone!!! The camera, the design, the display, everything is just the best! I am so excited about it. One UI is such a great UI to use. Thanks a lot.","stars":5}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/605f0daad0a67f001977b89a">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="Preeti Gupta" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              Preeti Gupta
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>2 reviews</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>IN</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
# ...
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/60573953f85d7509fc11fb19?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>,
#  <div class="review-card review-card--has-stack">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="5635b5e60000ff0001e72568" data-reviewmid="60554ec5f85d750bf4f9b7c1" id="60554ec5f85d750bf4f9b7c1">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/60554ec5f85d750bf4f9b7c1","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"5635b5e60000ff0001e72568","consumerName":"MISTI  HAMMER","reviewId":"60554ec5f85d750bf4f9b7c1","reviewHeader":"If I could rate it a zero or even a…","reviewBody":"If I could rate it a zero or even a negative number I would. I have never been treated so wrong by any company. After at least 12 attempts to have my ice maker “fixed” Samsung finally agreed to “refund” me for my refrigerator. After 3 months I still have not received my refund. December 10th I received an email stating my refund was sent. On December 27th I still had not received my refund. From December 27th I have called them every week. In February I was told the check was cashed already. I explained to them I never received my refund. I was called a liar and told that it was my problem not theirs. Never once have they tried to contact me or investigate what happened with my check. They’ve never tried to verify my signature or provided me with a copy of the cashed check as I have asked for every week that I called. I had to defend myself over their accusations that I cashed the check I never received!!! I was told on March 17th that the check was cashed and they are not writing me a new one. I had to contact the BBB as well as post on any and all social media to let people know not to buy Samsung appliances. They made me remove my warranty stickers and send that to them so now I have no warranty and no refund. I will never buy a Samsung product again and advise you not to buy Samsung products either. The irony of all this is it was on the news last night that there is a class action lawsuit for the ice makers and Samsung not recalling this product after so many complaints!!!","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/5635b5e60000ff0001e72568">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="MISTI  HAMMER" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              MISTI  HAMMER
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>6 reviews</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>US</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-20T01:24:21+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/60554ec5f85d750bf4f9b7c1">
#                          If I could rate it a zero or even a…
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  If I could rate it a zero or even a negative number I would. I have never been treated so wrong by any company. After at least 12 attempts to have my ice maker “fixed” Samsung finally agreed to “refund” me for my refrigerator. After 3 months I still have not received my refund. December 10th I received an email stating my refund was sent. On December 27th I still had not received my refund. From December 27th I have called them every week. In February I was told the check was cashed already. I explained to them I never received my refund. I was called a liar and told that it was my problem not theirs. Never once have they tried to contact me or investigate what happened with my check. They’ve never tried to verify my signature or provided me with a copy of the cashed check as I have asked for every week that I called. I had to defend myself over their accusations that I cashed the check I never received!!! I was told on March 17th that the check was cashed and they are not writing me a new one. I had to contact the BBB as well as post on any and all social media to let people know not to buy Samsung appliances. They made me remove my warranty stickers and send that to them so now I have no warranty and no refund. I will never buy a Samsung product again and advise you not to buy Samsung products either. The irony of all this is it was on the news last night that there is a class action lawsuit for the ice makers and Samsung not recalling this product after so many complaints!!!
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="60554ec5f85d750bf4f9b7c1">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/60554ec5f85d750bf4f9b7c1?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  <div class="review-stack" data-review-count="2" data-review-stack="">
#  <script data-initial-state="review-stack-info" type="application/json">
#  {"latestReviewId":"60554ec5f85d750bf4f9b7c1","numberOfReviewsInStack":2}
#  </script>
#  <button class="button review-stack__show-button" data-review-stack-show-button="">
#              Read 1 more review about Samsung Electronics
#          </button>
#  <div class="review-stack__container" data-review-stack-container="">
#  <div class="review-stack__disclaimer review-stack__disclaimer--hidden" data-review-stack-disclaimer="" role="button">
#                  Only the latest review will count in the company's TrustScore
#              </div>
#  <div class="review-stack__container__stack" data-review-stack-container-stack=""></div>
#  </div>
#  </div>
#  </div>,
#  <div class="review-card">
#  <article class="review" data-review-domain-id="46d2a2ef000064000500986a" data-review-domain-name="www.samsung.com" data-review-is-reported="false" data-review-user-id="6053fae036087e001b48d188" data-reviewmid="6053faf7f85d750bf4f8a115" id="6053faf7f85d750bf4f8a115">
#  <script data-initial-state="review-info" type="application/json">
#  {"socialShareUrl":"https://ca.trustpilot.com/reviews/6053faf7f85d750bf4f8a115","businessUnitId":"46d2a2ef000064000500986a","businessUnitDisplayName":"Samsung Electronics","consumerId":"6053fae036087e001b48d188","consumerName":"Raul Ferrera","reviewId":"6053faf7f85d750bf4f8a115","reviewHeader":"Damn samsung!!","reviewBody":"Damn samsung!!! I have ordered 2 s21 ultra, I have receive part of the order in 2 months and I\u0027m still calling samsung fckng customer service every week 2 or 3 times that day, make me waste my time and patience,  never receive an information about where is my stuff and agents keeps making escalations every time and that doesn\u0027t help at all!! Damn I hate to be dealing with this company!!!!","stars":1}
#  </script>
#  <aside class="review__consumer-information">
#  <a class="consumer-information" data-track-link="{'target': 'Consumer profile', 'name': 'consumer-info'}" href="/users/6053fae036087e001b48d188">
#  <consumer-review-picture class="consumer-information__picture" consumer-display-name="Raul Ferrera" image-class="consumer-information__picture">
#  </consumer-review-picture>
#  <div class="consumer-information__details">
#  <div class="consumer-information__name" v-pre="">
#              Raul Ferrera
#          </div>
#  <div class="consumer-information__data">
#  <div class="consumer-information__review-count">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_pencil"></use></svg>
#  <span>1 review</span>
#  </div>
#  <div class="consumer-information__location" v-pre="">
#  <svg class="consumer-information__review-icon"><use xlink:href="#icon_map-pin"></use></svg>
#  <span>US</span>
#  </div>
#  </div>
#  </div>
#  </a>
#  </aside>
#  <section class="review__content">
#  <div class="review-content">
#  <div class="review-content__header" v-pre="">
#  <div class="review-content-header">
#  <div class="star-rating star-rating--medium">
#  <img alt="1 star: Bad" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-1.svg"/>
#  </div>
#  <div class="review-content-header__dates">
#  <script data-initial-state="review-dates" type="application/json">
#  {"publishedDate":"2021-03-19T01:14:31+00:00","updatedDate":null,"reportedDate":null}
#  </script>
#  <review-dates :published-date="publishedDate" :reported-date="reportedDate" :updated-date="updatedDate"></review-dates>
#  </div>
#  <div class="review-content-header__review-labels">
#  </div>
#  </div>
#  </div>
#  <div class="review-content__body" v-pre="">
#  <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/6053faf7f85d750bf4f8a115">
#                          Damn samsung!!
#                  </a>
#  </h2>
#  <p class="review-content__text">
#                  Damn samsung!!! I have ordered 2 s21 ultra, I have receive part of the order in 2 months and I'm still calling samsung fckng customer service every week 2 or 3 times that day, make me waste my time and patience,  never receive an information about where is my stuff and agents keeps making escalations every time and that doesn't help at all!! Damn I hate to be dealing with this company!!!!
#              </p>
#  </div>
#  </div>
#  </section>
#  <div class="review__actions">
#  <div class="review-actions">
#  <div class="review-actions__main">
#  <brand-find-useful-button :initial-find-useful-count="0" :is-enabled="true" review-id="6053faf7f85d750bf4f8a115">
#  <div class="review-action">
#  <button class="button button--subtle button--subtle-label-below">
#  <span class="icon icon-thumbs-up"></span>
#  <span>Useful</span>
#  </button>
#  </div>
#  </brand-find-useful-button>
#  <brand-share-button :business-app-cookie-name="businessAppCookieName" :business-app-share-url="businessAppShareUrl" :review-info="reviewInfo" :share-in-business-app-enabled="shareInBusinessAppEnabled">
#  <div class="review-action brand-share-button-wrapper">
#  <div>
#  <button class="button button--subtle button--subtle-label-below brand-share-button">
#  <span class="icon icon-share"></span>
#  <span>Share</span>
#  </button>
#  <div ref="tooltipContainer"></div>
#  </div>
#  </div>
#  </brand-share-button>
#  <a class="button button--subtle button--subtle-label-below" data-reply-as-company-button="" data-track-link="{ 'name': 'reply-as-company', 'target': 'Business App', 'legacyName': 'ReplyAsCompany' }" href="https://businessapp.b2b.trustpilot.com/reviews/6053faf7f85d750bf4f8a115?businessUnitId=46d2a2ef000064000500986a" rel="nofollow" style="display: none" target="_blank" title="Reply as company">
#  <svg class="icon">
#  <use xlink:href="#icon_reply"></use>
#  </svg>
#  <span>Reply</span>
#  </a>
#  </div>
#  <div class="review-actions__notify-wrapper">
#  <script data-initial-state="businessAppUrl" type="application/json">
#  "https://businessapp.b2b.trustpilot.com/"
#  </script>
#  <button class="button button--subtle button--subtle-label-below notify-compliance-button" data-notify-content-integrity-team="" type="button">
#  <svg class="icon icon-flag--outline flag-svg" fill="red"><use xlink:href="#icon_flag_outline"></use></svg>
#  <span class="already-flagged-message" data-already-flagged-message="">
#              You've already flagged this
#          </span>
#  </button>
#  </div>
#  </div>
#  </div>
#  <div class="reporting"></div>
#  </article>
#  </div>]

# %%
review_data = []

for i in range(len(reviews)):
    
    con = reviews[i].script.contents
    
    con1 = json.dumps(con)
    con2 = con1.split(',')
    
    try:
    
        review_data.append(
        {
            'URL': con2[0].strip().split('\\"')[3],
            'business_unit':con2[2].strip().split('\\"')[3],
            'reviewer_id':con2[3].strip().split('\\"')[3],
            'reviewer_name':con2[4].strip().split('\\"')[3],
            'review_header':con2[6].strip().split('\\"')[3],
            'review_body':reviews[i].p.text.strip(),
            'star_rating': [s for s in con2[-1].strip().split('\\"')[2] if s.isdigit()],
            'location':reviews[i].div.contents[3].contents[3].text.strip(),
            'count_review_by_user':reviews[i].div.contents[3].contents[1].text.strip()
        }
        )
    
    except:
        print('invalid review')

# %%
r_df = pd.DataFrame(review_data)

# %%
r_df
# Out:
#                                                   URL business_unit  \
# 0   https://ca.trustpilot.com/reviews/60315b13f85d...        Amazon
# 1   https://ca.trustpilot.com/reviews/60314f28f85d...        Amazon
# 2   https://ca.trustpilot.com/reviews/60314d86f85d...        Amazon
# 3   https://ca.trustpilot.com/reviews/60313c90f85d...        Amazon
# 4   https://ca.trustpilot.com/reviews/60312f9df85d...        Amazon
# 5   https://ca.trustpilot.com/reviews/60312d98f85d...        Amazon
# 6   https://ca.trustpilot.com/reviews/60312bdaf85d...        Amazon
# 7   https://ca.trustpilot.com/reviews/60311bcdf85d...        Amazon
# 8   https://ca.trustpilot.com/reviews/6031148af85d...        Amazon
# 9   https://ca.trustpilot.com/reviews/6030f2eef85d...        Amazon
# 10  https://ca.trustpilot.com/reviews/6030855bf85d...        Amazon
# 11  https://ca.trustpilot.com/reviews/603083d5f85d...        Amazon
# 12  https://ca.trustpilot.com/reviews/60305769f85d...        Amazon
# 13  https://ca.trustpilot.com/reviews/60304cfcf85d...        Amazon
# 14  https://ca.trustpilot.com/reviews/6030036bf85d...        Amazon
# 15  https://ca.trustpilot.com/reviews/602ff6f6f85d...        Amazon
# 16  https://ca.trustpilot.com/reviews/602fd064f85d...        Amazon
# 17  https://ca.trustpilot.com/reviews/602fd02df85d...        Amazon
# 18  https://ca.trustpilot.com/reviews/602f8a93f85d...        Amazon
# 19  https://ca.trustpilot.com/reviews/602f58edf85d...        Amazon
#
#                  reviewer_id     reviewer_name  \
# 0   60315b094b6bae001a4128b7       Gary Osborn
# 1   5357e87f00006400016fad3d    KENNETH CAIRNS
# 2   58fd17810000ff000a904fd2      Mark Gregory
# 3   60313b74bae32a0019ebd436              gbgb
# 4   560938da0000ff0001df072a      Jamie Holder
# 5   60312d90d37e8b001a2c1ed4     Harry Leschke
# 6   60312bd1d37e8b001a2c1d9a        liam lewis
# 7   6031172abb3faf00199565bd     Scot Trekkers
# 8   602ba23eb9d941001aeedfac   Mark Richardson
# 9   602fbb834d2c59001b358e0c          J. Kunes
# 10  60308291d5456800192147ac         Don Smith
# 11  5adaa5e64de5666d343fe9f0       Craig Stone
# 12  60304e5ad37e8b001a2bb4d8      Kyle Delaney
# 13  6009535b6d10d9001a61ab78                TM
# 14  603003654d2c59001b35bd27    Cynthia Miller
# 15  5dfc887931bb5aa9d88cd625         lucielcma
# 16  5ff645195d959f001a6522ac               KYG
# 17  602fd028c78f6b001ab69c18      Corey Gillam
# 18  60151a2b9e67fc001980b8f2             N. L.
# 19  5e345ae8e5a4c780618c3b75  Michael Hamilton
#
#                                         review_header  \
# 0       Amazon is great about taking your money\u2026
# 1                           Amazon Let Down By Hermes
# 2        What on earth is going on with my item\u2026
# 3   \ud83d\ude32\u2658  \uff43\uff55\uff53\uff54\u...
# 4        Two items ordered on my account not by\u2026
# 5                            Delivery date never met.
# 6               Prime + 24 hours for an investigation
# 7                             Very happy Prime Member
# 8                                   Highly impressed.
# 9                                      Lost 3 returns
# 10  Some of the best customer service I\\u0027ve\u...
# 11                                    Too big to care
# 12                        Disdainful customer service
# 13                                 Never had an issue
# 14                                 Amazon tanks twice
# 15                                        Love amazon
# 16        Too Many Chinese Counterfeit Knockoffs Sold
# 17                        Don\\u0027t buy from Amazon
# 18       Used to be a good company but all this\u2026
# 19       I ordered 4 Bitcoin Miners from Amazon\u2026
#
#                                           review_body star_rating location  \
# 0   Amazon is great about taking your money throug...         [1]       US
# 1   No problem with Amazon usually until today. Ha...         [1]       GB
# 2   What on earth is going on with my item because...         [1]       GB
# 3   Two items ordered on my account not by me, con...         [2]       IN
# 4   Two items ordered on my account not by me, con...         [1]       GB
# 5   Amazon puts a delivery date on the order, but ...         [1]       US
# 6   No matter what I do they always mess up my ord...         [1]       GB
# 7   Absolutely love Amazon. It has been a lifeline...         [5]       GB
# 8   Ordered a few items in the January sales and a...         [4]       GB
# 9   Customer service has hit an all time low.Retur...         [1]       US
# 10  Some of the best customer service I've ever ex...         [5]       US
# 11  I ordered a pet carrier and the sell page said...         [1]       US
# 12  Even ignoring the corruption, the profiteering...         [1]       US
# 13  Never had an issue, fast delivery and good pro...         [5]       GB
# 14  It has really gotten bad. Not worth the money....         [1]       US
# 15  Love amazon, they have a massive variety of pr...         [5]       GB
# 16  More and more of the products on Amazon are co...         [1]       US
# 17  Ordered a few different item within a few days...         [1]       US
# 18  Used to be a good company but all this is in t...         [1]       TH
# 19  I ordered 4 Bitcoin Miners from Amazon on Jan ...         [1]       GB
#
#    count_review_by_user
# 0              1 review
# 1            11 reviews
# 2            11 reviews
# 3             2 reviews
# 4             5 reviews
# 5              1 review
# 6              1 review
# 7             3 reviews
# 8             5 reviews
# 9             2 reviews
# 10            2 reviews
# 11            5 reviews
# 12            2 reviews
# 13            4 reviews
# 14             1 review
# 15            7 reviews
# 16            7 reviews
# 17             1 review
# 18            3 reviews
# 19            6 reviews

# %%
r_df.to_excel("reviews.xlsx")
